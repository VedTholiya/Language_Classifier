# %%
import pandas as pd
import numpy as np
from io import StringIO

# %% [markdown]
# building dataframe for one language

# %%
df = pd.read_json('am-ET.jsonl', lines = True)
df.head()
# Out:
#    id locale partition scenario             intent  \
# 0   0  am-ET      test    alarm          alarm_set
# 1   1  am-ET     train    alarm          alarm_set
# 2   2  am-ET     train    alarm          alarm_set
# 3   3  am-ET      test    audio  audio_volume_mute
# 4   4  am-ET     train    audio  audio_volume_mute
#
#                                     utt  \
# 0  በዚህ ሳምንት ከንጋቱ አስራአንድ ሰዓት ከእንቅልፍ አንቃኝ
# 1            አርብ ዘጠኝ ኤ. ኤም. ሰዓት ላይ አንቃኝ
# 2         ከሁለት ሰአት በኀላ ሚጠራ የማንቂያ ደውል ያዝ
# 3                                   ጸጥታ
# 4                              ኦሊ ዝም በል
#
#                                            annot_utt  worker_id  \
# 0  [date : በዚህ ሳምንት] [time : ከንጋቱ አስራአንድ ሰዓት] ከእን...         18
# 1       [date : አርብ] [time : ዘጠኝ ኤ. ኤም.] ሰዓት ላይ አንቃኝ         18
# 2             [time : ከሁለት ሰአት በኀላ ሚጠራ] የማንቂያ ደውል ያዝ         60
# 3                                                ጸጥታ         49
# 4                                           ኦሊ ዝም በል         49
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16521 entries, 0 to 16520
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           16521 non-null  int64
#  1   locale       16521 non-null  object
#  2   partition    16521 non-null  object
#  3   scenario     16521 non-null  object
#  4   intent       16521 non-null  object
#  5   utt          16521 non-null  object
#  6   annot_utt    16521 non-null  object
#  7   worker_id    16521 non-null  int64
#  8   slot_method  16521 non-null  object
#  9   judgments    16521 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# #### We add token feature column

# %%
 df['Token']=df['utt'].str.split(' ')

# %%
df
# Out:
#           id locale partition scenario             intent  \
# 0          0  am-ET      test    alarm          alarm_set
# 1          1  am-ET     train    alarm          alarm_set
# 2          2  am-ET     train    alarm          alarm_set
# 3          3  am-ET      test    audio  audio_volume_mute
# 4          4  am-ET     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  am-ET     train    email        email_query
# 16517  17177  am-ET     train    email        email_query
# 16518  17178  am-ET     train    email        email_query
# 16519  17179  am-ET      test    email        email_query
# 16520  17180  am-ET     train    email        email_query
#
#                                         utt  \
# 0      በዚህ ሳምንት ከንጋቱ አስራአንድ ሰዓት ከእንቅልፍ አንቃኝ
# 1                አርብ ዘጠኝ ኤ. ኤም. ሰዓት ላይ አንቃኝ
# 2             ከሁለት ሰአት በኀላ ሚጠራ የማንቂያ ደውል ያዝ
# 3                                       ጸጥታ
# ...

# %%
len(df)
# Out:
# 16521

# %%
df = df.drop(['id' , 'scenario' ,'intent', 'annot_utt' , 'worker_id','slot_method','judgments'], axis = 1)

# %%
df.head()
# Out:
#   locale partition                                   utt  \
# 0  am-ET      test  በዚህ ሳምንት ከንጋቱ አስራአንድ ሰዓት ከእንቅልፍ አንቃኝ
# 1  am-ET     train            አርብ ዘጠኝ ኤ. ኤም. ሰዓት ላይ አንቃኝ
# 2  am-ET     train         ከሁለት ሰአት በኀላ ሚጠራ የማንቂያ ደውል ያዝ
# 3  am-ET      test                                   ጸጥታ
# 4  am-ET     train                              ኦሊ ዝም በል
#
#                                           Token
# 0  [በዚህ, ሳምንት, ከንጋቱ, አስራአንድ, ሰዓት, ከእንቅልፍ, አንቃኝ]
# 1            [አርብ, ዘጠኝ, ኤ., ኤም., ሰዓት, ላይ, አንቃኝ]
# 2         [ከሁለት, ሰአት, በኀላ, ሚጠራ, የማንቂያ, ደውል, ያዝ]
# 3                                         [ጸጥታ]
# 4                                  [ኦሊ, ዝም, በል]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16521 entries, 0 to 16520
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   locale     16521 non-null  object
#  1   partition  16521 non-null  object
#  2   utt        16521 non-null  object
#  3   Token      16521 non-null  object
# dtypes: object(4)
# memory usage: 516.4+ KB

# %% [markdown]
# #### Constructing a dataframe for all the 27 languages with 4 feature columns

# %%
languages = ["af-ZA.jsonl",'de-DE.jsonl', "da-DK.jsonl", "de-DE.jsonl", "en-US.jsonl", "es-ES.jsonl", "fr-FR.jsonl", "fi-FI.jsonl", "hu-HU.jsonl", "is-IS.jsonl", "it-IT.jsonl", "jv-ID.jsonl",
    "lv-LV.jsonl", "ms-MY.jsonl", "nb-NO.jsonl", "nl-NL.jsonl", "pl-PL.jsonl", "pt-PT.jsonl", "ro-RO.jsonl", "ru-RU.jsonl", "sl-SL.jsonl", "sv-SE.jsonl", "sq-AL.jsonl", "sw-KE.jsonl", "tl-PH.jsonl", "tr-TR.jsonl", "vi-VN.jsonl", "cy-GB.jsonl"]

# %%
df_fin = pd.concat([pd.read_json(i, lines=True) for i in languages],axis=0)

# %%
df_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 462588 entries, 0 to 16520
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           462588 non-null  int64
#  1   locale       462588 non-null  object
#  2   partition    462588 non-null  object
#  3   scenario     462588 non-null  object
#  4   intent       462588 non-null  object
#  5   utt          462588 non-null  object
#  6   annot_utt    462588 non-null  object
#  7   worker_id    462588 non-null  int64
#  8   slot_method  446067 non-null  object
#  9   judgments    446067 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 38.8+ MB

# %%
df_fin
# Out:
#           id locale partition scenario             intent  \
# 0          0  af-ZA      test    alarm          alarm_set
# 1          1  af-ZA     train    alarm          alarm_set
# 2          2  af-ZA     train    alarm          alarm_set
# 3          3  af-ZA      test    audio  audio_volume_mute
# 4          4  af-ZA     train    audio  audio_volume_mute
# ...      ...    ...       ...      ...                ...
# 16516  17176  cy-GB     train    email        email_query
# 16517  17177  cy-GB     train    email        email_query
# 16518  17178  cy-GB     train    email        email_query
# 16519  17179  cy-GB      test    email        email_query
# 16520  17180  cy-GB     train    email        email_query
#
#                                                    utt  \
# 0                 maak my wakker om vyf v. m. die week
# 1              maak my wakker nege-uur v. m. op vrydag
# 2                stel 'n alarm vir twee ure van nou af
# ...

# %%
df_re = df_fin[['locale','partition','utt']]
df_re
# Out:
#       locale partition                                              utt
# 0      af-ZA      test             maak my wakker om vyf v. m. die week
# 1      af-ZA     train          maak my wakker nege-uur v. m. op vrydag
# 2      af-ZA     train            stel 'n alarm vir twee ure van nou af
# 3      af-ZA      test                                             stil
# 4      af-ZA     train                                  janneman stilte
# ...      ...       ...                                              ...
# 16516  cy-GB     train                               a oes gennyf ebyst
# 16517  cy-GB     train                             pa ebyst sy'n newydd
# 16518  cy-GB     train  a oes gennyf unrhyw ebyst newydd oddi wrth john
# 16519  cy-GB      test                   ydy john wedi anfon ebost i fi
# 16520  cy-GB     train                         gwiriwch ebost wrth john
#
# [462588 rows x 3 columns]

# %%
df_re['token'] = df_re['utt'].str.split()
# Out:
# C:\Users\vedpr\AppData\Local\Temp\ipykernel_34112\1073888633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_re['token'] = df_re['utt'].str.split()

# %%
df_re
# Out:
#       locale partition                                              utt  \
# 0      af-ZA      test             maak my wakker om vyf v. m. die week
# 1      af-ZA     train          maak my wakker nege-uur v. m. op vrydag
# 2      af-ZA     train            stel 'n alarm vir twee ure van nou af
# 3      af-ZA      test                                             stil
# 4      af-ZA     train                                  janneman stilte
# ...      ...       ...                                              ...
# 16516  cy-GB     train                               a oes gennyf ebyst
# 16517  cy-GB     train                             pa ebyst sy'n newydd
# 16518  cy-GB     train  a oes gennyf unrhyw ebyst newydd oddi wrth john
# 16519  cy-GB      test                   ydy john wedi anfon ebost i fi
# 16520  cy-GB     train                         gwiriwch ebost wrth john
#
#                                                    token
# ...

# %%
df_re.sample(10)
# Out:
#       locale partition                                                utt  \
# 3708   da-DK     train                                         sluk audio
# 4821   de-DE     train                            eine tasse kaffee bitte
# 11202  fr-FR       dev       quel est le pub le plus proche dans la ville
# 4282   hu-HU     train                                         soundcloud
# 6826   af-ZA     train              verwyder al my kalender gebeurtenisse
# 1097   tr-TR     train                         alarmı sabah saat beşe kur
# 55     tr-TR     train        paket servis köri istiyorum tavsiyen var mı
# 15856  nb-NO       dev                           hvor mange eposter i dag
# 7243   hu-HU     train  adj hozzá emlékeztetőt ma estére hogy átvegyem...
# 5056   en-US     train                                     umbrella later
#
#                                                    token
# 3708                                       [sluk, audio]
# ...

# %%
loc = ['af-ZA', 'da-DK', 'de-DE', 'en-US', 'es-ES', 'fr-FR', 'fi-FI', 'hu-HU', 'is-IS', 'it-IT', 'jv-ID', 'lv-LV',
'ms-MY', 'nb-NO', 'nl-NL', 'pl-PL', 'pt-PT', 'ro-RO', 'ru-RU', 'sl-SL', 'sv-SE', 'sq-AL', 'sw-KE', 'tl-PH', 'tr-TR', 'vi-VN', 'cy-GB']

# %% [markdown]
# #### Let's get the 27 files for each of the language

# %%
grouped = df_re.groupby('locale')
for value, group in grouped:
    result_df = group[['utt']]
    filename = f"output_{value}.csv"
    result_df.to_csv(filename, index=False) #Every csv file have same size containing 16521 sentences.

# %% [markdown]
# ##### Task 2

# %%
train =  df_re[df['partition'] == 'train']
# Out:
# C:\Users\vedpr\AppData\Local\Temp\ipykernel_34112\2521223558.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   train =  df_re[df['partition'] == 'train']

# %%
train
# Out:
#       locale partition                                              utt  \
# 1      af-ZA     train          maak my wakker nege-uur v. m. op vrydag
# 2      af-ZA     train            stel 'n alarm vir twee ure van nou af
# 4      af-ZA     train                                  janneman stilte
# 5      af-ZA     train                                             stop
# 6      af-ZA     train        janneman onderbreek dit vir tien sekondes
# ...      ...       ...                                              ...
# 16515  cy-GB     train                 anfon helo drwy whatsapp i vikki
# 16516  cy-GB     train                               a oes gennyf ebyst
# 16517  cy-GB     train                             pa ebyst sy'n newydd
# 16518  cy-GB     train  a oes gennyf unrhyw ebyst newydd oddi wrth john
# 16520  cy-GB     train                         gwiriwch ebost wrth john
#
#                                                    token
# ...

# %%
X_train = train.drop(['locale','partition','token'], axis = 1).astype(str)
X_train.shape
# Out:
# (322392, 1)

# %%
X_train=X_train.values

# %%
X_train.shape
# Out:
# (322392, 1)

# %%
y_train = train['locale'].values

# %%
y_train.shape
# Out:
# (322392,)

# %%
len(y_train),len(X_train)
# Out:
# (322392, 322392)

# %%
# y_train.shape = (322392,1)

# %% [markdown]
# Now to use the multinomial bayes model we need to assign a vector to each of these strings into a vector of numbers.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

# %%
# vectorizer = TfidfVectorizer(lowercase=True, stop_words='english', ngram_range=(1, 2))

# %%
# X_tra = vectorizer.fit_transform( X_train)

# %%
vectorizer=CountVectorizer()

# %%
X_train.shape=(1,322392)

# %%
X_train=X_train[0]

# %%
X_train
# Out:
# array(['maak my wakker nege-uur v. m. op vrydag',
#        "stel 'n alarm vir twee ure van nou af", 'janneman stilte', ...,
#        "pa ebyst sy'n newydd",
#        'a oes gennyf unrhyw ebyst newydd oddi wrth john',
#        'gwiriwch ebost wrth john'], dtype=object)

# %%
model =make_pipeline(TfidfVectorizer(),MultinomialNB())
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
model.predict(['Elle est médecin .'])
# Out:
# array(['fr-FR'], dtype='<U5')

# %%
val_data=df_re[df_re['partition']=='dev']

# %%
val_dat=val_data['utt'].values

# %%
pred=model.predict(val_dat)

# %%
y_test=val_data['locale'].values

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        af-ZA       0.97      0.98      0.97      2026
#        cy-GB       0.99      1.00      0.99      2014
#        da-DK       0.96      0.94      0.95      2069
#        de-DE       1.00      0.91      0.95      4469
#        en-US       0.98      0.97      0.97      2070
#        es-ES       0.98      0.99      0.98      2018
#        fi-FI       0.98      1.00      0.99      1998
#        fr-FR       0.99      0.99      0.99      2028
#        hu-HU       0.97      1.00      0.99      1981
#        is-IS       0.99      1.00      0.99      2010
#        it-IT       0.99      1.00      0.99      2019
#        jv-ID       0.98      0.99      0.99      2016
#        lv-LV       0.99      1.00      0.99      2011
#        ms-MY       0.99      0.99      0.99      2042
#        nb-NO       0.93      0.97      0.95      1967
#        nl-NL       0.97      0.98      0.97      2005
# ...

# %%
testing_data=df_re['utt'].values

# %%
testing_data
# Out:
# array(['maak my wakker om vyf v. m. die week',
#        'maak my wakker nege-uur v. m. op vrydag',
#        "stel 'n alarm vir twee ure van nou af", ...,
#        'a oes gennyf unrhyw ebyst newydd oddi wrth john',
#        'ydy john wedi anfon ebost i fi', 'gwiriwch ebost wrth john'],
#       dtype=object)

# %% [markdown]
# # Task 3

# %%
df_re['locale'].str.split('-')
# Out:
# 0        [af, ZA]
# 1        [af, ZA]
# 2        [af, ZA]
# 3        [af, ZA]
# 4        [af, ZA]
#            ...
# 16516    [cy, GB]
# 16517    [cy, GB]
# 16518    [cy, GB]
# 16519    [cy, GB]
# 16520    [cy, GB]
# Name: locale, Length: 462588, dtype: object

# %%
country= df_re['locale'].str.split('-')

# %%
country_train=[]
for i in country:
    country_train.append(i[1])

# %%
country_train=np.array(country_train)

# %%
country_train.shape=(1,462588)

# %%
country_train=country_train[0]

# %%
country_train
# Out:
# array(['ZA', 'ZA', 'ZA', ..., 'GB', 'GB', 'GB'], dtype='<U2')

# %%
df_re['country']=country_train
# Out:
# C:\Users\vedpr\AppData\Local\Temp\ipykernel_34112\3485275334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_re['country']=country_train

# %%
df_re
# Out:
#       locale partition                                              utt  \
# 0      af-ZA      test             maak my wakker om vyf v. m. die week
# 1      af-ZA     train          maak my wakker nege-uur v. m. op vrydag
# 2      af-ZA     train            stel 'n alarm vir twee ure van nou af
# 3      af-ZA      test                                             stil
# 4      af-ZA     train                                  janneman stilte
# ...      ...       ...                                              ...
# 16516  cy-GB     train                               a oes gennyf ebyst
# 16517  cy-GB     train                             pa ebyst sy'n newydd
# 16518  cy-GB     train  a oes gennyf unrhyw ebyst newydd oddi wrth john
# 16519  cy-GB      test                   ydy john wedi anfon ebost i fi
# 16520  cy-GB     train                         gwiriwch ebost wrth john
#
#                                                    token country
# ...

# %%
df_re['country'].value_counts()
# Out:
# country
# DE    33042
# ZA    16521
# NL    16521
# VN    16521
# TR    16521
# PH    16521
# KE    16521
# AL    16521
# SE    16521
# SL    16521
# RU    16521
# RO    16521
# PT    16521
# PL    16521
# NO    16521
# MY    16521
# LV    16521
# ID    16521
# IT    16521
# IS    16521
# HU    16521
# FI    16521
# FR    16521
# ES    16521
# US    16521
# DK    16521
# GB    16521
# Name: count, dtype: int64

# %%
continents={'ZA':'Africa','NL':'Europe','VN':'Asia','TR':'Europe','PH':'Asia','KE':'Africa','AL':'Africa','SE':'Europe','SL':'Africa','RU':'Asia','RO':'Europe','PT':'Europe','PL':'Europe','NO':'Europe','DK':'Europe','MY':'Asia','LV':'Europe','ID':'Asia','IT':'Europe','IS':'Europe','HU':'Europe','FI':'Europe','FR':'Europe','ES':'Europe','US':'North America','DE':'Europe','GB':'Europe'}

# %%
df_re['continents']=list(df_re['country'].map(continents))
# Out:
# C:\Users\vedpr\AppData\Local\Temp\ipykernel_34112\1256768102.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_re['continents']=list(df_re['country'].map(continents))

# %%
df_re
# Out:
#       locale partition                                              utt  \
# 0      af-ZA      test             maak my wakker om vyf v. m. die week
# 1      af-ZA     train          maak my wakker nege-uur v. m. op vrydag
# 2      af-ZA     train            stel 'n alarm vir twee ure van nou af
# 3      af-ZA      test                                             stil
# 4      af-ZA     train                                  janneman stilte
# ...      ...       ...                                              ...
# 16516  cy-GB     train                               a oes gennyf ebyst
# 16517  cy-GB     train                             pa ebyst sy'n newydd
# 16518  cy-GB     train  a oes gennyf unrhyw ebyst newydd oddi wrth john
# 16519  cy-GB      test                   ydy john wedi anfon ebost i fi
# 16520  cy-GB     train                         gwiriwch ebost wrth john
#
#                                                    token country continents
# ...

# %%
val_new = df_re[df_re['partition']=='dev']

# %%
val_new
# Out:
#       locale partition                                                utt  \
# 11     af-ZA       dev                      skakel die ligte af asseblief
# 17     af-ZA       dev                       verdof die ligte in die gang
# 24     af-ZA       dev                         maak die vertrek donkerder
# 26     af-ZA       dev                            maak die woonstel skoon
# 30     af-ZA       dev  skoonmaak is goed stof is so sleg doen nou jou...
# ...      ...       ...                                                ...
# 16462  cy-GB       dev                     adroddwch unrhyw e-byst newydd
# 16478  cy-GB       dev            sawl neges heb eu darllen sydd gennyf i
# 16481  cy-GB       dev                ymateb i'r ebost dw'i newydd derbyn
# 16494  cy-GB       dev               wnaeth bert ysgrifennu ataf i heddiw
# 16508  cy-GB       dev                  beth yw'r cyfeiriad ar gyfer alex
#
#                                                    token country continents
# ...

# %%
train_new = df_re[df_re['partition']=='train']
train_new
# Out:
#       locale partition                                              utt  \
# 1      af-ZA     train          maak my wakker nege-uur v. m. op vrydag
# 2      af-ZA     train            stel 'n alarm vir twee ure van nou af
# 4      af-ZA     train                                  janneman stilte
# 5      af-ZA     train                                             stop
# 6      af-ZA     train        janneman onderbreek dit vir tien sekondes
# ...      ...       ...                                              ...
# 16515  cy-GB     train                 anfon helo drwy whatsapp i vikki
# 16516  cy-GB     train                               a oes gennyf ebyst
# 16517  cy-GB     train                             pa ebyst sy'n newydd
# 16518  cy-GB     train  a oes gennyf unrhyw ebyst newydd oddi wrth john
# 16520  cy-GB     train                         gwiriwch ebost wrth john
#
#                                                    token country continents
# ...

# %%
test_new = df_re[df_re['partition']=='test']
test_new
# Out:
#       locale partition                                                utt  \
# 0      af-ZA      test               maak my wakker om vyf v. m. die week
# 3      af-ZA      test                                               stil
# 8      af-ZA      test                      pienk is al wat ons nodig het
# 14     af-ZA      test                          en die donkerte het geval
# 19     af-ZA      test     janneman skakel die ligte af in die slaapkamer
# ...      ...       ...                                                ...
# 16492  cy-GB      test  mae fy ffrind john wedi danfon gwahoddiad ataf...
# 16497  cy-GB      test    gwiria fy ebost am unrhyw ebost newydd wrth joe
# 16498  cy-GB      test     a oes gennyf unrhyw ebost newydd oddi wrth jac
# 16511  cy-GB      test          hysbysa fi pan fod arwel yn fy ebostio fi
# 16519  cy-GB      test                     ydy john wedi anfon ebost i fi
#
#                                                    token country continents
# ...

# %%
X=df_re['utt'].values
X
# Out:
# array(['maak my wakker om vyf v. m. die week',
#        'maak my wakker nege-uur v. m. op vrydag',
#        "stel 'n alarm vir twee ure van nou af", ...,
#        'a oes gennyf unrhyw ebyst newydd oddi wrth john',
#        'ydy john wedi anfon ebost i fi', 'gwiriwch ebost wrth john'],
#       dtype=object)

# %%
y=train_new['continents'].values

# %%
y
# Out:
# array(['Africa', 'Africa', 'Africa', ..., 'Europe', 'Europe', 'Europe'],
#       dtype=object)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

# %%
model1=make_pipeline(TfidfVectorizer(),QuadraticDiscriminantAnalysis())

# %%
train_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 322392 entries, 1 to 16520
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   locale      322392 non-null  object
#  1   partition   322392 non-null  object
#  2   utt         322392 non-null  object
#  3   token       322392 non-null  object
#  4   country     322392 non-null  object
#  5   continents  322392 non-null  object
# dtypes: object(6)
# memory usage: 17.2+ MB

# %%
train_new['continents'].value_counts()
# Out:
# continents
# Europe           207252
# Asia              57570
# Africa            46056
# North America     11514
# Name: count, dtype: int64

# %%
europe_train_1=train_new[train_new['continents']=='Europe'].sample(50000)

# %%
asia_train_2=train_new[train_new['continents']=='Asia'].sample(25000)

# %%
n_a_train_4=train_new[train_new['continents']=='North America'].sample(350)

# %%
africa_train_3=train_new[train_new['continents']=='Africa'].sample(20000)

# %%
train_new=pd.concat([europe_train_1,asia_train_2,n_a_train_4,africa_train_3],axis=0)

# %%
train_new.sample(10)
# Out:
#       locale partition                                                utt  \
# 6206   ru-RU     train  найди мне самую дешевую копию четырехчасового ...
# 5500   nb-NO     train                  kan du si meg klokken i new delhi
# 15135  fi-FI     train                  postaa päivitys twitter tililleni
# 15341  tr-TR     train  umut'a işten ne zaman çıkacağını soran bir e-p...
# 7415   vi-VN     train      lặp lại sự kiện này mỗi thứ sáu trong lịch
# 7843   jv-ID     train              busakno acara sabanjure ing tanggalan
# 8880   tl-PH     train  ipaalala sa akin ang tungkol sa pakikipagpulon...
# 8168   ro-RO     train                           șterge mi tot calendarul
# 7545   vi-VN     train                                 đặt một lời nhắc
# 10446  fi-FI     train                         mitä mun ostos listalla on
#
#                                                    token country continents
# 6206   [найди, мне, самую, дешевую, копию, четырехчас...      RU       Asia
# ...

# %%
X=train_new['utt'].values

# %%
X
# Out:
# array(['onko kalenterissani yhtään tapahtumaa tälle viikolle',
#        'tynnwch yr holl eitemau ar fy nghalendr',
#        'hey schreib karotten da drauf', ...,
#        'të lutem më vendos një përkujtues për takimin e sotshëm në orën pesë pasdite',
#        'ni kiwango gani cha ubadilishaji wa dola ya marekani na shilingi ya kenya',
#        'skuhaj kavo'], dtype=object)

# %%
for i in range(0,len(X)):
    X[i]=X[i][:35]

# %%
X[5000]
# Out:
# 'como a imprensa está reagindo aos p'

# %%
y=train_new['continents'].values

# %%
y
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
vectorizer=CountVectorizer(stop_words='english')

# %%
vectorizer
# Out:
# CountVectorizer(stop_words='english')

# %%
testing_data=vectorizer.fit_transform(testing_data)

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

print(ENGLISH_STOP_WORDS)
# Out:
# frozenset({'hereafter', 'at', 'call', 'thereafter', 'must', 'your', 'couldnt', 'even', 'well', 'so', 'thereupon', 'most', 'himself', 'found', 'afterwards', 'you', 'to', 'every', 'might', 'fill', 'four', 'part', 'something', 'along', 'off', 'cant', 'in', 'across', 'while', 'take', 'ours', 'yourselves', 'un', 'interest', 'third', 'she', 'between', 'within', 'upon', 'us', 'whereafter', 'he', 'hundred', 'below', 'rather', 'become', 'do', 'am', 'ten', 'see', 'eight', 'mill', 'been', 'front', 'thereby', 'often', 'it', 'becomes', 'beside', 'another', 'up', 'thru', 'be', 'have', 'further', 'thick', 'beforehand', 'always', 'whose', 'less', 'as', 'please', 'anyway', 'yourself', 'would', 'perhaps', 'without', 'after', 'elsewhere', 'onto', 'also', 'about', 'each', 'side', 'eg', 'many', 'cry', 'this', 'until', 'whereas', 'beyond', 'somehow', 'move', 'made', 'again', 'somewhere', 'due', 'anyone', 'fifteen', 'anything', 'her', 'above', 'anyhow', 'others', 'which', 'became', 'myself', 'thin', 'now',
# ...

# %%
dvectorizer = TfidfVectorizer(stop_words=["english",'Arabic','Danish','Dutch','Finnish','French','German','Hungarian','Italian','Kazakh','Norwegian','Portuguese','Romanian','Russian','Spanish','Swedish','Turkish'],lowercase=True)

# %%
vectorizer
# Out:
# TfidfVectorizer(stop_words=['english', 'Arabic', 'Danish', 'Dutch', 'Finnish',
#                             'French', 'German', 'Hungarian', 'Italian',
#                             'Kazakh', 'Norwegian', 'Portuguese', 'Romanian',
#                             'Russian', 'Spanish', 'Swedish', 'Turkish'],
#                 strip_accents='ascii')

# %%
from  sklearn.discriminant_analysis import LinearDiscriminantAnalysis as lda

# %%
X_sparse_1=vectorizer.fit_transform(X)

# %%
X_sparse_1
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 462008 stored elements and shape (95350, 62157)>

# %%
from sklearn.decomposition import TruncatedSVD

# %%
svd = TruncatedSVD(n_components=385)  
X_reduced = svd.fit_transform(X_sparse_1)

# %%
X_reduced.shape
# Out:
# (95350, 385)

# %%
model_lda=lda()

# %%
model_lda.fit(X_reduced,y)
# Out:
# LinearDiscriminantAnalysis()

# %%
val_X_data=val_new['utt'].values

# %%
X_sparse_val_1=vectorizer.fit_transform(val_X_data)

# %%
X_sparse_val_1
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 339919 stored elements and shape (56924, 51171)>

# %%
svd = TruncatedSVD(n_components=385) 
X_val_reduced = svd.fit_transform(X_sparse_val_1)

# %%
pred=model_lda.predict(X_val_reduced)

# %%
y_test=val_new['continents'].values

# %%
print(classification_report(y_test,pred))
# Out:
#                precision    recall  f1-score   support
#
#        Africa       0.11      0.12      0.11      8132
#          Asia       0.06      0.07      0.06     10165
#        Europe       0.61      0.59      0.60     36594
# North America       0.00      0.00      0.00      2033
#
#      accuracy                           0.41     56924
#     macro avg       0.19      0.19      0.19     56924
#  weighted avg       0.42      0.41      0.41     56924

# %%
model_qda=QuadraticDiscriminantAnalysis()

# %%
model_qda.fit(X_reduced,y)
# Out:
# C:\Users\vedpr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\discriminant_analysis.py:947: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# QuadraticDiscriminantAnalysis()

# %%
pred=model_qda.predict(X_val_reduced)

# %%
X=test_new['utt'].values

# %%
X=vectorizer.fit_transform(X)

# %%
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 495181 stored elements and shape (83272, 64581)>

# %%
svd = TruncatedSVD(n_components=385)  
X_test_reduced = svd.fit_transform(X)

# %%
X_test_reduced
# Out:
# array([[ 8.36358279e-02, -7.00676256e-03,  2.24892383e-01, ...,
#         -1.86748783e-02,  2.31111772e-02, -5.16212214e-03],
#        [ 4.31335583e-04, -8.13788878e-05,  6.02776087e-04, ...,
#          1.10901014e-03,  1.05543591e-03, -2.03734227e-03],
#        [ 8.93214968e-02, -2.24146995e-02,  1.66089942e-01, ...,
#         -4.37282144e-03,  1.48199530e-02,  1.35657854e-02],
#        ...,
#        [ 1.36400501e-03,  4.32627946e-04,  7.59634024e-04, ...,
#          1.53652844e-02, -3.24994188e-03, -1.04400407e-02],
#        [ 3.29266137e-03,  6.83553079e-04,  1.34657357e-03, ...,
#          2.65101935e-03,  1.72515892e-02,  2.19815412e-02],
#        [ 5.31643117e-03,  1.92017675e-03,  3.39156330e-03, ...,
#         -8.03313369e-03,  8.23109912e-03,  2.96021992e-02]])

# %%
y_test=test_new['continents'].values

# %%
y_test
# Out:
# array(['Africa', 'Africa', 'Africa', ..., 'Europe', 'Europe', 'Europe'],
#       dtype=object)

# %%
pred=model_qda.predict(X_test_reduced)

# %%
pred
# Out:
# array(['Europe', 'Africa', 'Europe', ..., 'Europe', 'Europe', 'Europe'],
#       dtype=object)

# %%
y_test
# Out:
# array(['Africa', 'Africa', 'Africa', ..., 'Europe', 'Europe', 'Europe'],
#       dtype=object)

# %%
print(classification_report(y_test,pred))
# Out:
# C:\Users\vedpr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\vedpr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                precision    recall  f1-score   support
#
#        Africa       0.08      0.05      0.06     11896
# ...
